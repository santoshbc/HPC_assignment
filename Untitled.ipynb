# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
first=pd.read_csv("firstGuess.csv")
first.head()
# Out:
#    X     Y
# 0  1  31.5
# 1  2  33.0
# 2  3  34.5
# 3  4  36.0
# 4  5  37.5

# %%
plt.figure(figsize=(10,8))
plt.plot(first.X,first.Y,color='green')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()

# %%
second=pd.read_csv("Secondguess.csv")
second.head()
# Out:
#      x     y
# 0  0.0  20.0
# 1  1.0  21.3
# 2  2.0  22.6
# 3  3.0  23.9
# 4  4.0  25.2

# %%
plt.figure(figsize=(10,8))
plt.plot(second.x,second.y,color='green')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()

# %%
third=pd.read_csv("Thirdguess.csv")
third.head()
# Out:
#      x     y
# 0  0.0  10.0
# 1  1.0  11.1
# 2  2.0  12.2
# 3  3.0  13.3
# 4  4.0  14.4

# %%
plt.figure(figsize=(10,8))
plt.plot(third.x,third.y,color='green')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()

# %%
best=pd.read_csv("best_guess.csv")
best.head()
# Out:
#      x      y
# 0  0.0  31.63
# 1  1.0  32.84
# 2  2.0  34.05
# 3  3.0  35.26
# 4  4.0  36.47

# %%
plt.figure(figsize=(10,8))
plt.plot(best.x,best.y,color='red')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()

# %%
plt.figure(figsize=(10,8))
# plt.plot(org.X,org.Y,color='green')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(first.X,first.Y,color='green')
plt.plot(second.x,second.y,color='green')
plt.plot(third.x,third.y,color='green')
plt.plot(best.x,best.y,color='red')
plt.scatter(sc.X_axis,sc.Y_axis,color='blue')
plt.grid()
plt.xlabel("X-axis",fontsize=12)
plt.ylabel("Y-axis",fontsize=12)
# plt.title(First guess)
plt.show()
